# %%
import pandas as pd
import numpy as np
import random
import sklearn.datasets as datasets
import sys

sys.path.insert(1, '..')
from check_data_consistency import DataConsistencyChecker

# %%
pd.options.display.max_columns = 1000
pd.options.display.max_colwidth = 1000
pd.options.display.max_rows = 1000
pd.options.display.width = 10000

# %%
data = datasets.fetch_california_housing()
df = pd.read_csv("resume_data.csv") #https://www.kaggle.com/datasets/saugataroyarghya/resume-dataset
df.head(2)
# Out:
#   address                                                                                                                                                                                                                                                        career_objective                                                                                                                                                                                                                                                      skills                                                  educational_institution_name                                     degree_names     passing_years educational_results    result_types         major_field_of_studies professional_company_names company_urls   start_dates      end_dates                                          related_skils_in_job             positions locations                                                                                                                                                                                                                                                                                                                                                                                                         responsibilities extra_curricular_activity_types extra_curricular_organization_names extra_curricular_organization_links role_positions languages proficiency_levels certification_providers certification_skills online_links issue_dates expiry_dates              ﻿job_position_name                                                                        educationaL_requirements experiencere_requirement age_requirement                                                                                                                                                                                                                                                                                                                                                                                                       responsibilities.1 skills_required  matched_score
# 0     NaN  Big data analytics working and database warehouse manager with robust experience in handling all kinds of data. I have also used multiple cloud infrastructure services and am well acquainted with them. Currently in search of role that offers more of development.  ['Big Data', 'Hadoop', 'Hive', 'Python', 'Mapreduce', 'Spark', 'Java', 'Machine Learning', 'Cloud', 'Hdfs', 'YARN', 'Core Java', 'Data Science', 'C++', 'Data Structures', 'DBMS', 'RDBMS', 'Informatica', 'Talend', 'Amazon Redshift', 'Microsoft Azure']                ['The Amity School of Engineering & Technology (ASET), Noida']                                       ['B.Tech']          ['2019']             ['N/A']          [None]                ['Electronics']              ['Coca-COla']       [None]  ['Nov 2019']  ['Till Date']                                                [['Big Data']]  ['Big Data Analyst']   ['N/A']                                                                                                                                                                                                                                                 Technical Support\nTroubleshooting\nCollaboration\nDocumentation\nSystem Monitoring\nSoftware Deployment\nTraining & Mentorship\nIndustry Trends\nField Visits\n\n\n\n\n                             NaN                                 NaN                                 NaN            NaN       NaN                NaN                     NaN                  NaN          NaN         NaN          NaN        Senior Software Engineer                               B.Sc in Computer Science & Engineering from a reputed university.          At least 1 year             NaN                                                                                                                                                                                                                                                 Technical Support\nTroubleshooting\nCollaboration\nDocumentation\nSystem Monitoring\nSoftware Deployment\nTraining & Mentorship\nIndustry Trends\nField Visits\n\n\n\n\n             NaN       0.850000
# 1     NaN                                                                                                                          Fresher looking to join as a data analyst and junior data scientist. Experienced in creating meaningful data dashboards and evaluation models.                                                                                                  ['Data Analysis', 'Data Analytics', 'Business Analysis', 'R', 'SAS', 'PowerBi', 'Tableau', 'Data Visualization', 'Business Analytics', 'Machine Learning']  ['Delhi University - Hansraj College', 'Delhi University - Hansraj College']  ['B.Sc (Maths)', 'M.Sc (Science) (Statistics)']  ['2015', '2018']      ['N/A', 'N/A']  ['N/A', 'N/A']  ['Mathematics', 'Statistics']        ['BIB Consultancy']      ['N/A']  ['Sep 2019']  ['Till Date']  [['Data Analysis', 'Business Analysis', 'Machine Learning']]  ['Business Analyst']   ['N/A']  Machine Learning Leadership\nCross-Functional Collaboration\nStrategy Development\nML/NLP Infrastructure\nPrototype Transformation\nML System Design\nAlgorithm Research\nApplication Development\nDataset Selection\nML Testing\nStatistical Analysis\nR&D in ML/NLP\nText Representation\nData Pipeline Design\nStatistical Data Analysis\nModel Training\nTeam Collaboration\nResearch Reporting\nAlgorithm Analysis                             NaN                                 NaN                                 NaN            NaN       NaN                NaN                     NaN                  NaN          NaN         NaN          NaN  Machine Learning (ML) Engineer  M.Sc in Computer Science & Engineering or in any relevant discipline from a reputed University       At least 5 year(s)             NaN  Machine Learning Leadership\nCross-Functional Collaboration\nStrategy Development\nML/NLP Infrastructure\nPrototype Transformation\nML System Design\nAlgorithm Research\nApplication Development\nDataset Selection\nML Testing\nStatistical Analysis\nR&D in ML/NLP\nText Representation\nData Pipeline Design\nStatistical Data Analysis\nModel Training\nTeam Collaboration\nResearch Reporting\nAlgorithm Analysis             NaN       0.750000

# %%
dc = DataConsistencyChecker()
dc.init_data(df)

# %%
# Run a small set of tests to start. In this example, we run a single test.

_ = dc.check_data_quality()
# Out:
# Executing test   0: MISSING_VALUES
# Executing test   1: RARE_VALUES
# Executing test   2: UNIQUE_VALUES
# Executing test   3: PREV_VALUES_DT
# Executing test   4: MATCHED_MISSING
# Executing test   5: OPPOSITE_MISSING
# Executing test   6: SAME_VALUES
# Executing test   7: SAME_OR_CONSTANT
# Executing test   8: UNIQUE_PAIR
# Executing test   9: POSITIVE
# Executing test  10: NEGATIVE
# Executing test  11: NUMBER_DECIMALS
# Executing test  12: RARE_DECIMALS
# Executing test  13: COLUMN_ORDERED_ASC
# Executing test  14: COLUMN_ORDERED_DESC
# Executing test  15: COLUMN_TENDS_ASC
# Executing test  16: COLUMN_TENDS_DESC
# Executing test  17: SIMILAR_PREVIOUS
# Executing test  18: UNUSUAL_ORDER_MAGNITUDE
# Executing test  19: FEW_NEIGHBORS
# Executing test  20: FEW_WITHIN_RANGE
# Executing test  21: VERY_SMALL
# Executing test  22: VERY_LARGE
# Executing test  23: VERY_SMALL_ABS
# Executing test  24: MULTIPLE_OF_CONSTANT
# Executing test  25: ROUNDING
# Executing test  26: NON_ZERO
# Executing test  27: LESS_THAN_ONE
# Executing test  28: GREATER_THAN_ONE
# Executing test  29: INVALID_NUMBERS
# Executing test  30: LARGER_DIFF_RANGE
# Executing test  31: LARGER_SAME_RANGE
# Executing test  32: MUCH_LARGER
# Executing test  33: SIMILAR_WRT_RATIO
# Executing test  34: SIMILAR_WRT_DIFF
# Executing test  35: SIMILAR_TO_INVERSE
# Executing test  36: SIMILAR_TO_NEGATIVE
# Executing test  37: CONSTANT_SUM
# Executing test  38: CONSTANT_DIFF
# Executing test  39: CONSTANT_PRODUCT
# Executing test  40: CONSTANT_RATIO
# Executing test  41: EVEN_MULTIPLE
# Executing test  42: RARE_COMBINATION
# Executing test  43: CORRELATED_NUMERIC
# Executing test  44: MATCHED_ZERO
# Executing test  45: OPPOSITE_ZERO
# Executing test  46: RUNNING_SUM
# Executing test  47: A_ROUNDED_B
# Executing test  48: MATCHED_ZERO_MISSING
# Executing test  49: SIMILAR_TO_DIFF
# Executing test  50: SIMILAR_TO_PRODUCT
# Executing test  51: SIMILAR_TO_RATIO
# Executing test  52: LARGER_THAN_SUM
# Executing test  53: SUM_OF_COLUMNS
# Executing test  54: MEAN_OF_COLUMNS
# Executing test  55: MIN_OF_COLUMNS
# Executing test  56: MAX_OF_COLUMNS
# Executing test  57: MATCHED_SET_POS_NEG
# Executing test  58: MATCHED_SET_ZERO_NON_ZERO
# Executing test  59: DECISION_TREE_REGRESSOR
# Executing test  60: LINEAR_REGRESSION
# Executing test  61: PREDICT_NULL_DT
# Executing test  62: EARLY_DATES
# Executing test  63: LATE_DATES
# Executing test  64: UNUSUAL_DAY_OF_WEEK
# Executing test  65: UNUSUAL_DAY_OF_MONTH
# Executing test  66: UNUSUAL_MONTH
# Executing test  67: UNUSUAL_HOUR
# Executing test  68: UNUSUAL_MINUTES
# Executing test  69: CONSTANT_DOM
# Executing test  70: CONSTANT_LAST_DOM
# Executing test  71: CONSTANT_GAP
# Executing test  72: LARGE_GAP
# Executing test  73: SMALL_GAP
# Executing test  74: LATER
# Executing test  75: SAME_DATE
# Executing test  76: SAME_MONTH
# Executing test  77: CORRELATED_DATES
# Executing test  78: LARGE_GIVEN_DATE
# Executing test  79: SMALL_GIVEN_DATE
# Executing test  80: BINARY_SAME
# Executing test  81: BINARY_OPPOSITE
# Executing test  82: BINARY_IMPLIES
# Executing test  83: BINARY_AND
# Executing test  84: BINARY_OR
# Executing test  85: BINARY_XOR
# Executing test  86: BINARY_NUM_SAME
# Executing test  87: BINARY_RARE_COMBINATION
# Executing test  88: BINARY_MATCHES_VALUES
# Executing test  89: BINARY_TWO_OTHERS_MATCH
# Executing test  90: BINARY_MATCHES_SUM
# Executing test  91: BLANK_VALUES
# Executing test  92: LEADING_WHITESPACE
# Executing test  93: TRAILING_WHITESPACE
# Executing test  94: FIRST_CHAR_ALPHA
# Executing test  95: FIRST_CHAR_NUMERIC
# Executing test  96: FIRST_CHAR_SMALL_SET
# Executing test  97: FIRST_CHAR_UPPERCASE
# Executing test  98: FIRST_CHAR_LOWERCASE
# Executing test  99: LAST_CHAR_SMALL_SET
# Executing test 100: COMMON_SPECIAL_CHARS
# Executing test 101: COMMON_CHARS
# Executing test 102: NUMBER_ALPHA_CHARS
# Executing test 103: NUMBER_NUMERIC_CHARS
# Executing test 104: NUMBER_ALPHANUMERIC_CHARS
# Executing test 105: NUMBER_NON-ALPHANUMERIC_CHARS
# Executing test 106: NUMBER_CHARS
# Executing test 107: NONPRINTABLE_CHARS
# Executing test 108: MANY_CHARS
# Executing test 109: FEW_CHARS
# Executing test 110: POSITION_NON-ALPHANUMERIC
# Executing test 111: CHARS_PATTERN
# Executing test 112: UPPERCASE
# Executing test 113: LOWERCASE
# Executing test 114: CHARACTERS_USED
# Executing test 115: FIRST_WORD_SMALL_SET
# Executing test 116: LAST_WORD_SMALL_SET
# Executing test 117: NUMBER_WORDS
# Executing test 118: LONGEST_WORDS
# Executing test 119: COMMON_WORDS
# Executing test 120: RARE_WORDS
# Executing test 121: GROUPED_STRINGS
# Executing test 122: RARE_PAIRS
# Executing test 123: RARE_PAIRS_FIRST_CHAR
# Executing test 124: RARE_PAIRS_FIRST_WORD
# Executing test 125: RARE_PAIRS_FIRST_WORD_VAL
# Executing test 126: SIMILAR_CHARACTERS
# Executing test 127: SIMILAR_NUM_CHARS
# Executing test 128: SIMILAR_WORDS
# Executing test 129: SIMILAR_NUM_WORDS
# Executing test 130: SAME_FIRST_CHARS
# Executing test 131: SAME_FIRST_WORD
# Executing test 132: SAME_LAST_WORD
# Executing test 133: SAME_ALPHA_CHARS
# Executing test 134: SAME_NUMERIC_CHARS
# Executing test 135: SAME_SPECIAL_CHARS
# Executing test 136: A_PREFIX_OF_B
# Executing test 137: A_SUFFIX_OF_B
# Executing test 138: B_CONTAINS_A
# Executing test 139: CORRELATED_ALPHA_ORDER
# Executing test 140: LARGE_GIVEN_VALUE
# Executing test 141: SMALL_GIVEN_VALUE
# Executing test 142: LARGE_GIVEN_PREFIX
# Executing test 143: SMALL_GIVEN_PREFIX
# Executing test 144: GROUPED_STRINGS_BY_NUMERIC
# Executing test 145: LARGE_GIVEN_PAIR
# Executing test 146: SMALL_GIVEN_PAIR
# Executing test 147: CORRELATED_GIVEN_VALUE
# Executing test 148: DECISION_TREE_CLASSIFIER
# Executing test 149: C_IS_A_OR_B
# Executing test 150: TWO_PAIRS
# Executing test 151: UNIQUE_SETS_VALUES
# Executing test 152: MISSING_VALUES_PER_ROW
# Executing test 153: ZERO_VALUES_PER_ROW
# Executing test 154: UNIQUE_VALUES_PER_ROW
# Executing test 155: NEGATIVE_VALUES_PER_ROW
# Executing test 156: SMALL_AVG_RANK_PER_ROW
# Executing test 157: LARGE_AVG_RANK_PER_ROW
#
# Data consistency check complete.
# Analysed 9,544 rows, 35 columns
# Executed 158 tests.
#
# Patterns without Exceptions:
# Found 91 patterns without exceptions
# 14 tests (8.86% of tests) identified at least one pattern without exceptions each.
# By default some patterns are not listed in calls to display_detailed_results().
#
# Patterns with Exceptions:
# Found 20 patterns with exceptions
# 10 tests (6.33% of tests) flagged at least one exception each.
# Flagged 489 row(s) with at least one exception.
# Flagged 16 column(s) with at least one exception.

# %%
# In the next few cells, we look at the output of the tests.

dc.summarize_patterns_and_exceptions()
# Out:
# Empty DataFrame
# Columns: [Test ID, Number Patterns without Exceptions, Number Patterns with Exceptions]
# Index: []

# %%
# Run a small set of tests to start. In this example, we run a single test.

_ = dc.check_data_quality(execute_list=['SIMILAR_PREVIOUS'])
# Out:
# Executing test  17: SIMILAR_PREVIOUS
#
# Data consistency check complete.
# Analysed 9,544 rows, 35 columns
# Executed 1 tests.
#
# Patterns without Exceptions:
# Found 0 patterns without exceptions
# 0 tests (0.00% of tests) identified at least one pattern without exceptions each.
# By default some patterns are not listed in calls to display_detailed_results().
#
# Patterns with Exceptions:
# Found 0 patterns with exceptions
# 0 tests (0.00% of tests) flagged at least one exception each.
# Flagged 0 row(s) with at least one exception.
# Flagged 0 column(s) with at least one exception.

# %%
dc.quick_report()
# Out:
# Some patterns not shown. Set show_short_list_only to False to see additional patterns.
#
#
#
#
# Patterns List (short list only):
#                       Test ID                                                                                                                                        Column(s)                                                                                   Description of Pattern  Pattern ID
# 5             MATCHED_MISSING  "educational_institution_name" AND "degree_names" AND "passing_years" AND "educational_results" AND "result_types" AND "major_field_of_studies"                   The columns consistently have missing values in the same rows, with 84 missing values.           5
# 6             MATCHED_MISSING     "professional_company_names" AND "company_urls" AND "start_dates" AND "end_dates" AND "related_skils_in_job" AND "positions" AND "locations"                   The columns consistently have missing values in the same rows, with 84 missing values.           6
# 7             MATCHED_MISSING       "extra_curricular_activity_types" AND "extra_curricular_organization_names" AND "extra_curricular_organization_links" AND "role_positions"                 The columns consistently have missing values in the same rows, with 6118 missing values.           7
# 8             MATCHED_MISSING                                                                                                             "languages" AND "proficiency_levels"  The columns "languages" (with 8844 Null values) and "proficiency_levels" (with 8844 Null values) con...           8
# 9             MATCHED_MISSING                                     "certification_providers" AND "certification_skills" AND "online_links" AND "issue_dates" AND "expiry_dates"                 The columns consistently have missing values in the same rows, with 7536 missing values.           9
# 10                SAME_VALUES                                                                                                      "responsibilities" AND "responsibilities.1"              The values in "responsibilities.1" are consistently the same as those in "responsibilities"          10
# 12              LESS_THAN_ONE                                                                                                                                    matched_score                                The column consistently contains values between -1.0, and 1.0 (inclusive)          12
# 16       FIRST_CHAR_SMALL_SET                                                                                                                                           skills  The column "skills" has 340 distinct values and contains values that consistently start with one of ...          16
# 17       FIRST_CHAR_SMALL_SET                                                                                                                     educational_institution_name  The column "educational_institution_name" has 328 distinct values and contains values that consisten...          17
# 18       FIRST_CHAR_SMALL_SET                                                                                                                                     degree_names  The column "degree_names" has 180 distinct values and contains values that consistently start with o...          18
# 19       FIRST_CHAR_SMALL_SET                                                                                                                                    passing_years  The column "passing_years" has 149 distinct values and contains values that consistently start with ...          19
# 20       FIRST_CHAR_SMALL_SET                                                                                                                           major_field_of_studies  The column "major_field_of_studies" has 210 distinct values and contains values that consistently st...          20
# 21       FIRST_CHAR_SMALL_SET                                                                                                                       professional_company_names  The column "professional_company_names" has 199 distinct values and contains values that consistentl...          21
# 22       FIRST_CHAR_SMALL_SET                                                                                                                                      start_dates  The column "start_dates" has 252 distinct values and contains values that consistently start with on...          22
# 23       FIRST_CHAR_SMALL_SET                                                                                                                                        end_dates  The column "end_dates" has 246 distinct values and contains values that consistently start with one ...          23
# 24       FIRST_CHAR_SMALL_SET                                                                                                                             related_skils_in_job  The column "related_skils_in_job" has 298 distinct values and contains values that consistently star...          24
# 25       FIRST_CHAR_SMALL_SET                                                                                                                                        positions  The column "positions" has 301 distinct values and contains values that consistently start with one ...          25
# 26       FIRST_CHAR_UPPERCASE                                                                                                                               ﻿job_position_name                                               The column consistently starts with an uppercase character          26
# 27       FIRST_CHAR_UPPERCASE                                                                                                                                  age_requirement                                               The column consistently starts with an uppercase character          27
# 28        LAST_CHAR_SMALL_SET                                                                                                                                           skills  The column "skills" has 340 distinct values and contains values that consistently end with one of ['...          28
# 29        LAST_CHAR_SMALL_SET                                                                                                                     educational_institution_name  The column "educational_institution_name" has 328 distinct values and contains values that consisten...          29
# 30        LAST_CHAR_SMALL_SET                                                                                                                                     degree_names  The column "degree_names" has 180 distinct values and contains values that consistently end with one...          30
# 31        LAST_CHAR_SMALL_SET                                                                                                                                    passing_years  The column "passing_years" has 149 distinct values and contains values that consistently end with on...          31
# 32        LAST_CHAR_SMALL_SET                                                                                                                           major_field_of_studies  The column "major_field_of_studies" has 210 distinct values and contains values that consistently en...          32
# 33        LAST_CHAR_SMALL_SET                                                                                                                       professional_company_names  The column "professional_company_names" has 199 distinct values and contains values that consistentl...          33
# 34        LAST_CHAR_SMALL_SET                                                                                                                                      start_dates  The column "start_dates" has 252 distinct values and contains values that consistently end with one ...          34
# 35        LAST_CHAR_SMALL_SET                                                                                                                                        end_dates  The column "end_dates" has 246 distinct values and contains values that consistently end with one of...          35
# 36        LAST_CHAR_SMALL_SET                                                                                                                             related_skils_in_job  The column "related_skils_in_job" has 298 distinct values and contains values that consistently end ...          36
# 37        LAST_CHAR_SMALL_SET                                                                                                                                        positions  The column "positions" has 301 distinct values and contains values that consistently end with one of...          37
# 38       COMMON_SPECIAL_CHARS                                                                                                                                           skills                                                   The column consistently contains the ], [ character(s)          38
# 39       COMMON_SPECIAL_CHARS                                                                                                                     educational_institution_name                                                The column consistently contains the ], [, ' character(s)          39
# 40       COMMON_SPECIAL_CHARS                                                                                                                                     degree_names                                                The column consistently contains the ], [, ' character(s)          40
# 41       COMMON_SPECIAL_CHARS                                                                                                                                    passing_years                                                   The column consistently contains the ], [ character(s)          41
# 42       COMMON_SPECIAL_CHARS                                                                                                                              educational_results                                                   The column consistently contains the ], [ character(s)          42
# 43       COMMON_SPECIAL_CHARS                                                                                                                                     result_types                                                   The column consistently contains the ], [ character(s)          43
# 44       COMMON_SPECIAL_CHARS                                                                                                                           major_field_of_studies                                                   The column consistently contains the ], [ character(s)          44
# 45       COMMON_SPECIAL_CHARS                                                                                                                       professional_company_names                                                The column consistently contains the ], [, ' character(s)          45
# 46       COMMON_SPECIAL_CHARS                                                                                                                                     company_urls                                                   The column consistently contains the ], [ character(s)          46
# 47       COMMON_SPECIAL_CHARS                                                                                                                                        end_dates                                                   The column consistently contains the ], [ character(s)          47
# 48       COMMON_SPECIAL_CHARS                                                                                                                             related_skils_in_job                                                   The column consistently contains the ], [ character(s)          48
# 49       COMMON_SPECIAL_CHARS                                                                                                                                        positions                                                The column consistently contains the ], [, ' character(s)          49
# 50       COMMON_SPECIAL_CHARS                                                                                                                                        locations                                                   The column consistently contains the ], [ character(s)          50
# 51       COMMON_SPECIAL_CHARS                                                                                                                                 responsibilities                                                     The column consistently contains the \n character(s)          51
# 52       COMMON_SPECIAL_CHARS                                                                                                              extra_curricular_organization_names                                                   The column consistently contains the ], [ character(s)          52
# 53       COMMON_SPECIAL_CHARS                                                                                                              extra_curricular_organization_links                                                   The column consistently contains the ], [ character(s)          53
# 54       COMMON_SPECIAL_CHARS                                                                                                                                   role_positions                                                   The column consistently contains the ], [ character(s)          54
# 55       COMMON_SPECIAL_CHARS                                                                                                                                        languages                                                The column consistently contains the [, ], ' character(s)          55
# 56       COMMON_SPECIAL_CHARS                                                                                                                               proficiency_levels                                                The column consistently contains the ], [, ' character(s)          56
# 57       COMMON_SPECIAL_CHARS                                                                                                                          certification_providers                                                   The column consistently contains the ], [ character(s)          57
# 58       COMMON_SPECIAL_CHARS                                                                                                                             certification_skills                                                   The column consistently contains the ], [ character(s)          58
# 59       COMMON_SPECIAL_CHARS                                                                                                                                     online_links                                                   The column consistently contains the ], [ character(s)          59
# 60       COMMON_SPECIAL_CHARS                                                                                                                                      issue_dates                                                   The column consistently contains the ], [ character(s)          60
# 61       COMMON_SPECIAL_CHARS                                                                                                                                     expiry_dates                                                   The column consistently contains the ], [ character(s)          61
# 62       COMMON_SPECIAL_CHARS                                                                                                                               responsibilities.1                                                     The column consistently contains the \n character(s)          62
# 63  POSITION_NON-ALPHANUMERIC                                                                                                                                           skills                              The column contains values consistently with ']' in position 1 from the end          63
# 64  POSITION_NON-ALPHANUMERIC                                                                                                                     educational_institution_name                              The column contains values consistently with ']' in position 1 from the end          64
# 65  POSITION_NON-ALPHANUMERIC                                                                                                                                     degree_names                              The column contains values consistently with ']' in position 1 from the end          65
# 66  POSITION_NON-ALPHANUMERIC                                                                                                                                    passing_years                              The column contains values consistently with ']' in position 1 from the end          66
# 67  POSITION_NON-ALPHANUMERIC                                                                                                                              educational_results                              The column contains values consistently with ']' in position 1 from the end          67
# 68  POSITION_NON-ALPHANUMERIC                                                                                                                                     result_types                              The column contains values consistently with ']' in position 1 from the end          68
# 69  POSITION_NON-ALPHANUMERIC                                                                                                                           major_field_of_studies                              The column contains values consistently with ']' in position 1 from the end          69
# 70  POSITION_NON-ALPHANUMERIC                                                                                                                       professional_company_names                              The column contains values consistently with ']' in position 1 from the end          70
# 71  POSITION_NON-ALPHANUMERIC                                                                                                                                     company_urls                              The column contains values consistently with ']' in position 1 from the end          71
# 72  POSITION_NON-ALPHANUMERIC                                                                                                                                      start_dates                              The column contains values consistently with ']' in position 1 from the end          72
# 73  POSITION_NON-ALPHANUMERIC                                                                                                                                        end_dates                              The column contains values consistently with ']' in position 1 from the end          73
# 74  POSITION_NON-ALPHANUMERIC                                                                                                                             related_skils_in_job                              The column contains values consistently with ']' in position 1 from the end          74
# 75  POSITION_NON-ALPHANUMERIC                                                                                                                                        positions                              The column contains values consistently with ']' in position 1 from the end          75
# 76  POSITION_NON-ALPHANUMERIC                                                                                                                                        locations                              The column contains values consistently with ']' in position 1 from the end          76
# 77  POSITION_NON-ALPHANUMERIC                                                                                                                  extra_curricular_activity_types                              The column contains values consistently with ']' in position 1 from the end          77
# 78  POSITION_NON-ALPHANUMERIC                                                                                                              extra_curricular_organization_names                              The column contains values consistently with ']' in position 1 from the end          78
# 79  POSITION_NON-ALPHANUMERIC                                                                                                              extra_curricular_organization_links                              The column contains values consistently with ']' in position 1 from the end          79
# 80  POSITION_NON-ALPHANUMERIC                                                                                                                                   role_positions                              The column contains values consistently with ']' in position 1 from the end          80
# 81  POSITION_NON-ALPHANUMERIC                                                                                                                                        languages                              The column contains values consistently with ']' in position 1 from the end          81
# 82  POSITION_NON-ALPHANUMERIC                                                                                                                               proficiency_levels                              The column contains values consistently with ']' in position 1 from the end          82
# 83  POSITION_NON-ALPHANUMERIC                                                                                                                          certification_providers                              The column contains values consistently with ']' in position 1 from the end          83
# 84  POSITION_NON-ALPHANUMERIC                                                                                                                             certification_skills                              The column contains values consistently with ']' in position 1 from the end          84
# 85  POSITION_NON-ALPHANUMERIC                                                                                                                                     online_links                              The column contains values consistently with ']' in position 1 from the end          85
# 86  POSITION_NON-ALPHANUMERIC                                                                                                                                      issue_dates                              The column contains values consistently with ']' in position 1 from the end          86
# 87  POSITION_NON-ALPHANUMERIC                                                                                                                                     expiry_dates                              The column contains values consistently with ']' in position 1 from the end          87
# 88               COMMON_WORDS                                                                                                                                  age_requirement                   The values in column "age_requirement" consistently contain the word(s) 'Age', 'years'          88
# 89          SIMILAR_NUM_WORDS                                                                                                 "experiencere_requirement" AND "age_requirement"  The columns "experiencere_requirement" and "age_requirement" consistently have a similar number of w...          89
# 90           SAME_FIRST_CHARS                                                                                                      "responsibilities" AND "responsibilities.1"      Columns "responsibilities" and "responsibilities.1" consistently share the same first 24 characters          90
#
#
#
#
# Patterns by Test and Feature:
#                           address career_objective skills educational_institution_name degree_names passing_years educational_results result_types major_field_of_studies professional_company_names company_urls start_dates end_dates related_skils_in_job positions locations responsibilities extra_curricular_activity_types extra_curricular_organization_names extra_curricular_organization_links role_positions languages proficiency_levels certification_providers certification_skills online_links issue_dates expiry_dates ﻿job_position_name educationaL_requirements experiencere_requirement age_requirement responsibilities.1 skills_required matched_score
# Test ID
# MISSING_VALUES                                                                                                                                                                                                                                                                                  ✔                                                                                                                                                                                                                                                         ✔                        ✔                                                           ✔                             ✔
# MATCHED_MISSING                                                                      ✔            ✔             ✔                   ✔            ✔                      ✔                          ✔            ✔           ✔         ✔                    ✔         ✔         ✔                                                ✔                                   ✔                                   ✔              ✔         ✔                  ✔                       ✔                    ✔            ✔           ✔            ✔
# SAME_VALUES                                                                                                                                                                                                                                                                                     ✔                                                                                                                                                                                                                                                                                                                                              ✔
# POSITIVE                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ✔
# LESS_THAN_ONE                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ✔
# FIRST_CHAR_ALPHA                                 ✔                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ✔                                                                 ✔
# FIRST_CHAR_SMALL_SET                                    ✔                            ✔            ✔             ✔                                                       ✔                          ✔                        ✔         ✔                    ✔         ✔
# FIRST_CHAR_UPPERCASE                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ✔                                                                 ✔
# LAST_CHAR_SMALL_SET                                     ✔                            ✔            ✔             ✔                                                       ✔                          ✔                        ✔         ✔                    ✔         ✔
# COMMON_SPECIAL_CHARS                                    ✔                            ✔            ✔             ✔                   ✔            ✔                      ✔                          ✔            ✔                     ✔                    ✔         ✔         ✔                ✔                                                                   ✔                                   ✔              ✔         ✔                  ✔                       ✔                    ✔            ✔           ✔            ✔                                                                                                       ✔
# POSITION_NON-ALPHANUMERIC                               ✔                            ✔            ✔             ✔                   ✔            ✔                      ✔                          ✔            ✔           ✔         ✔                    ✔         ✔         ✔                                                ✔                                   ✔                                   ✔              ✔         ✔                  ✔                       ✔                    ✔            ✔           ✔            ✔
# COMMON_WORDS                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ✔
# SIMILAR_NUM_WORDS                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ✔               ✔
# SAME_FIRST_CHARS                                                                                                                                                                                                                                                                                ✔                                                                                                                                                                                                                                                                                                                                              ✔
#
#
#
#
# Exceptions List:
#                       Test ID                                       Column(s)                                                                                   Description of Pattern  Number of Exceptions  Issue ID
# 0                    NON_ZERO                                   matched_score                                       The column consistently contains non-zero values, with exceptions.                     1         0
# 1         LAST_CHAR_SMALL_SET                                career_objective  The column "career_objective" has 171 distinct values and contains values that consistently end with...                    28         1
# 2        COMMON_SPECIAL_CHARS                                         address                                    The column consistently contains the , character(s), with exceptions.                    28         2
# 3        COMMON_SPECIAL_CHARS                                     start_dates                              The column consistently contains the ], [, ' character(s), with exceptions.                    28         3
# 4        COMMON_SPECIAL_CHARS                 extra_curricular_activity_types                              The column consistently contains the ], [, ' character(s), with exceptions.                    28         4
# 5        NUMBER_NUMERIC_CHARS                                career_objective          The column contains values with consistently 0, 1, 2, or 5 numeric characters, with exceptions.                    28         5
# 6        NUMBER_NUMERIC_CHARS                                    degree_names                      The column contains values with consistently 0 numeric characters, with exceptions.                    34         6
# 7        NUMBER_NUMERIC_CHARS                      professional_company_names                 The column contains values with consistently 0 or 2 numeric characters, with exceptions.                    28         7
# 8        NUMBER_NUMERIC_CHARS             extra_curricular_organization_names                      The column contains values with consistently 0 numeric characters, with exceptions.                    28         8
# 9        NUMBER_NUMERIC_CHARS                                  role_positions                 The column contains values with consistently 0 or 1 numeric characters, with exceptions.                    56         9
# 10       NUMBER_NUMERIC_CHARS                                    expiry_dates                 The column contains values with consistently 0 or 4 numeric characters, with exceptions.                    28        10
# 11                 MANY_CHARS                                career_objective  Some values were unusually long. Any values with length greater than 945.0 characters were flagged, ...                    28        11
# 12                 MANY_CHARS                                    company_urls  Some values were unusually long. Any values with length greater than 83.5 characters were flagged, g...                    28        12
# 13                 MANY_CHARS                            related_skils_in_job  Some values were unusually long. Any values with length greater than 1133.5 characters were flagged,...                    28        13
# 14               NUMBER_WORDS                                career_objective  The values in column "career_objective" have word count with 25th percentile 0.0 words and 75th perc...                    28        14
# 15                 RARE_WORDS                                    company_urls  The values in column "company_urls" consistently use only words common to this column, with exceptio...                    28        15
# 16      RARE_PAIRS_FIRST_WORD               "result_types" AND "company_urls"                                            Rare combinations of first words were found, [('None', 'N')].                    28        16
# 17  RARE_PAIRS_FIRST_WORD_VAL                  "locations" AND "company_urls"  Rare combinations of the first word in locations and the value in company_urls were found, [['City',...                    28        17
# 18         SMALL_GIVEN_PREFIX  "educationaL_requirements" AND "matched_score"  "matched_score" contains very small values given the first word/prefix ['Bachelors', 'Diploma', 'M']...                    18        18
# 19         SMALL_GIVEN_PREFIX  "experiencere_requirement" AND "matched_score"  "matched_score" contains very small values given the first word/prefix ['3', '4'] in "experiencere_r...                    19        19
#
#
#
#
# Exceptions Summary by Test and Feature:
#                           address career_objective skills educational_institution_name degree_names passing_years educational_results result_types major_field_of_studies professional_company_names company_urls start_dates end_dates related_skils_in_job positions locations responsibilities extra_curricular_activity_types extra_curricular_organization_names extra_curricular_organization_links role_positions languages proficiency_levels certification_providers certification_skills online_links issue_dates expiry_dates ﻿job_position_name educationaL_requirements experiencere_requirement age_requirement responsibilities.1 skills_required matched_score
# Test ID
# NON_ZERO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# LAST_CHAR_SMALL_SET                             28
# COMMON_SPECIAL_CHARS           28                                                                                                                                                                                          28                                                                                                  28
# NUMBER_NUMERIC_CHARS                            28                                               34                                                                                               28                                                                                                                                                               28                                                 56                                                                                                              28
# MANY_CHARS                                      28                                                                                                                                                             28                                         28
# NUMBER_WORDS                                    28
# RARE_WORDS                                                                                                                                                                                                     28
# RARE_PAIRS_FIRST_WORD                                                                                                                           28                                                             28
# RARE_PAIRS_FIRST_WORD_VAL                                                                                                                                                                                      28                                                             28
# SMALL_GIVEN_PREFIX                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                18                       19                                                               37
#
#
#
#
# Exceptions Summary by Test:
#                            Number of Columns Flagged At Least Once  Number of Issues Total
# Test ID
# NON_ZERO                                                         1                       1
# LAST_CHAR_SMALL_SET                                              1                      28
# COMMON_SPECIAL_CHARS                                             3                      84
# NUMBER_NUMERIC_CHARS                                             6                     202
# MANY_CHARS                                                       3                      84
# NUMBER_WORDS                                                     1                      28
# RARE_WORDS                                                       1                      28
# RARE_PAIRS_FIRST_WORD                                            1                      28
# RARE_PAIRS_FIRST_WORD_VAL                                        1                      28
# SMALL_GIVEN_PREFIX                                               2                      37
#
#
#
#
# Summary of Patterns and Exceptions (all tests):
#                       Test ID Number Patterns without Exceptions Number Patterns with Exceptions
# 0              MISSING_VALUES                                  5
# 1             MATCHED_MISSING                                  5
# 2                 SAME_VALUES                                  1
# 3                    POSITIVE                                  1
# 4                    NON_ZERO                                                                  1
# 5               LESS_THAN_ONE                                  1
# 6            FIRST_CHAR_ALPHA                                  3
# 7        FIRST_CHAR_SMALL_SET                                 10
# 8        FIRST_CHAR_UPPERCASE                                  2
# 9         LAST_CHAR_SMALL_SET                                 10                               1
# 10       COMMON_SPECIAL_CHARS                                 25                               3
# 11       NUMBER_NUMERIC_CHARS                                                                  6
# 12                 MANY_CHARS                                                                  3
# 13  POSITION_NON-ALPHANUMERIC                                 25
# 14               NUMBER_WORDS                                                                  1
# 15               COMMON_WORDS                                  1
# 16                 RARE_WORDS                                                                  1
# 17      RARE_PAIRS_FIRST_WORD                                                                  1
# 18  RARE_PAIRS_FIRST_WORD_VAL                                                                  1
# 19          SIMILAR_NUM_WORDS                                  1
# 20           SAME_FIRST_CHARS                                  1
# 21         SMALL_GIVEN_PREFIX                                                                  2
#
#
#
#
# Final Scores by Row of the Data:
# Final Scores by Feature:
# Final Scores by Test:

# %%
dc.display_detailed_results(test_id_list=['COMMON_WORDS'])
# Out:
# ----------------------------------------------------------------------------
# Columns(s): age_requirement
# Pattern found (without exceptions)
# Description: The values in column "age_requirement" consistently contain the word(s) 'Age', 'years'
#
# Examples:
#            age_requirement
# 3       Age 22 to 30 years
# 8       Age 25 to 40 years
# 10   Age at least 24 years
# 11   Age at least 28 years
# 18      Age 30 to 40 years
# 21      Age 25 to 35 years
# 27   Age at least 22 years
# 30      Age 18 to 30 years
# 47   Age at least 30 years
# 135     Age 25 to 30 years

# %%
for i in range(16,20):
  dc.display_detailed_results(issue_id_list=[i])
# Out:
# ******************************************************************************
# RARE_PAIRS_FIRST_WORD
# ******************************************************************************
#
#
# ----------------------------------------------------------------------------
# Columns(s): "result_types" AND "company_urls"
# Issue ID: 16
# A strong pattern, and exceptions to the pattern, were found.
#
# Description: Rare combinations of first words were found, [('None', 'N')].
# Number of exceptions: 28 (0.2934% of rows)
#
# Examples of values NOT flagged:
#                       result_types                                company_urls result_types First Word company_urls First Word
# 0                           [None]                                      [None]                    None                    None
# 1                   ['N/A', 'N/A']                                     ['N/A']                       N                       N
# 3                           [None]        [None, None, None, None, None, None]                    None                    None
# 4                           [None]              [None, None, None, None, None]                    None                    None
# 5                     [None, None]                          [None, None, None]                    None                    None
# 12                         ['N/A']                              ['N/A', 'N/A']                       N                       N
# 13  ['CGPA', 'Percentage', 'CGPA']                                [None, None]                    CGPA                    None
# 28                  ['N/A', 'N/A']                    [None, None, None, None]                       N                    None
# 95                         ['N/A']  [None, None, None, None, None, None, None]                       N                    None
#
# Examples of flagged values:
#       result_types           company_urls result_types First Word company_urls First Word
# 25    [None, None]  ['N/A', 'N/A', 'N/A']                    None                       N
# 47    [None, None]  ['N/A', 'N/A', 'N/A']                    None                       N
# 89    [None, None]  ['N/A', 'N/A', 'N/A']                    None                       N
# 290   [None, None]  ['N/A', 'N/A', 'N/A']                    None                       N
# 304   [None, None]  ['N/A', 'N/A', 'N/A']                    None                       N
# 347   [None, None]  ['N/A', 'N/A', 'N/A']                    None                       N
# 1892  [None, None]  ['N/A', 'N/A', 'N/A']                    None                       N
# 2081  [None, None]  ['N/A', 'N/A', 'N/A']                    None                       N
# 2795  [None, None]  ['N/A', 'N/A', 'N/A']                    None                       N
# 2876  [None, None]  ['N/A', 'N/A', 'N/A']                    None                       N
# ******************************************************************************
# RARE_PAIRS_FIRST_WORD_VAL
# ******************************************************************************
#
#
# ----------------------------------------------------------------------------
# Columns(s): "locations" AND "company_urls"
# Issue ID: 17
# A strong pattern, and exceptions to the pattern, were found.
#
# Description: Rare combinations of the first word in locations and the value in company_urls were found, [['City',
# "['N/A']"]].
# Number of exceptions: 28 (0.2934% of rows)
#
# Examples of values NOT flagged:
#                                                                                                            locations                                company_urls locations FIRST WORD
# 0                                                                                                            ['N/A']                                      [None]                    N
# 1                                                                                                            ['N/A']                                     ['N/A']                    N
# 3                                 ['City, State', 'City, State', 'City, State', 'City, State', 'City, State', 'N/A']        [None, None, None, None, None, None]                 City
# 4                                        ['City, State', 'City, State', 'City, State', 'City, State', 'City, State']              [None, None, None, None, None]                 City
# 5                                                                              ['City, State', 'City, State', 'N/A']                          [None, None, None]                 City
# 12                                                                                                    ['N/A', 'N/A']                              ['N/A', 'N/A']                    N
# 13                                                                                                    ['N/A', 'N/A']                                [None, None]                    N
# 25                                                                    ['Princeton, NJ', 'Remote', 'Cherry Hill, NJ']                       ['N/A', 'N/A', 'N/A']            Princeton
# 28                                                  ['City , State', 'City , State', 'City , State', 'City , State']                    [None, None, None, None]                 City
# 95  ['City , State', 'City , State', 'City , State', 'City , State', 'City , State', 'City , State', 'City , State']  [None, None, None, None, None, None, None]                 City
#
# Examples of flagged values:
#                locations company_urls locations FIRST WORD
# 632   ['City, Province']      ['N/A']                 City
# 988   ['City, Province']      ['N/A']                 City
# 1173  ['City, Province']      ['N/A']                 City
# 1352  ['City, Province']      ['N/A']                 City
# 1590  ['City, Province']      ['N/A']                 City
# 1694  ['City, Province']      ['N/A']                 City
# 1863  ['City, Province']      ['N/A']                 City
# 2493  ['City, Province']      ['N/A']                 City
# 2995  ['City, Province']      ['N/A']                 City
# 3416  ['City, Province']      ['N/A']                 City
#
#
#
#
#
# ******************************************************************************
# SMALL_GIVEN_PREFIX
# ******************************************************************************
#
#
# ----------------------------------------------------------------------------
# Columns(s): "educationaL_requirements" AND "matched_score"
# Issue ID: 18
# Unusual values were found.
#
# Description: "matched_score" contains very small values given the first word/prefix ['Bachelors', 'Diploma', 'M']
# in "educationaL_requirements" (Values that are small given any value of "educationaL_requirements"
# are not flagged by this test.).
# Number of exceptions: 18 (0.1886% of rows)
#
# Examples of values NOT flagged:
#                                                                            educationaL_requirements  matched_score educationaL_requirements FIRST WORD
# 0                                 B.Sc in Computer Science & Engineering from a reputed university.       0.850000                                   B
# 1    M.Sc in Computer Science & Engineering or in any relevant discipline from a reputed University       0.750000                                   M
# 4                                                     Bachelor of Science (BSc) in Computer Science       0.650000                            Bachelor
# 8                        Bachelor of Science (BSc) in Mechanical Engineering, Diploma in Mechanical       0.550000                            Bachelor
# 36                Bachelors or Masters degree in Computer Science, Engineering, or a related field.       0.816667                           Bachelors
# 38                                                                        Bachelor of Science (BSc)       0.716667                            Bachelor
# 40           Fresh graduates with a Bachelor’s degree in Mechanical Engineering or a related field.       0.783333                               Fresh
# 78           Fresh graduates with a Bachelor’s degree in Mechanical Engineering or a related field.       0.683333                               Fresh
# 102                      Bachelor of Science (BSc) in Mechanical Engineering, Diploma in Mechanical       0.350000                            Bachelor
# 214                                     Bachelor of Science (BSc) in Computer Science & Engineering       0.450000                            Bachelor
#
# Examples of flagged values:
#                                                                             educationaL_requirements  matched_score educationaL_requirements FIRST WORD
# 287                                                                         Diploma, Bachelor/Honors       0.316667                             Diploma
# 562   M.Sc in Computer Science & Engineering or in any relevant discipline from a reputed University       0.350000                                   M
# 699   M.Sc in Computer Science & Engineering or in any relevant discipline from a reputed University       0.450000                                   M
# 1221                                                                        Diploma, Bachelor/Honors       0.440000                             Diploma
# 1225               Bachelors or Masters degree in Computer Science, Engineering, or a related field.       0.350000                           Bachelors
# 2169  M.Sc in Computer Science & Engineering or in any relevant discipline from a reputed University       0.450000                                   M
# 2221  M.Sc in Computer Science & Engineering or in any relevant discipline from a reputed University       0.350000                                   M
# 2376                                                                        Diploma, Bachelor/Honors       0.306667                             Diploma
# 2863  M.Sc in Computer Science & Engineering or in any relevant discipline from a reputed University       0.250000                                   M
# 4025  M.Sc in Computer Science & Engineering or in any relevant discipline from a reputed University       0.350000                                   M
# ******************************************************************************
# SMALL_GIVEN_PREFIX
# ******************************************************************************
#
#
# ----------------------------------------------------------------------------
# Columns(s): "experiencere_requirement" AND "matched_score"
# Issue ID: 19
# Unusual values were found.
#
# Description: "matched_score" contains very small values given the first word/prefix ['3', '4'] in
# "experiencere_requirement" (Values that are small given any value of "experiencere_requirement" are
# not flagged by this test.).
# Number of exceptions: 19 (0.1991% of rows)
#
# Examples of values NOT flagged:
#     experiencere_requirement  matched_score experiencere_requirement FIRST WORD
# 0            At least 1 year       0.850000                                  At
# 1         At least 5 year(s)       0.750000                                  At
# 4           At least 4 years       0.650000                                  At
# 8               2 to 5 years       0.550000                                   2
# 38              5 to 8 years       0.716667                                   5
# 45              5 to 8 years       0.783333                                   5
# 92              5 to 8 years       0.683333                                   5
# 102             2 to 5 years       0.350000                                   2
# 124         At least 3 years       0.816667                                  At
# 214         At least 2 years       0.450000                                  At
#
# Examples of flagged values:
#      experiencere_requirement  matched_score experiencere_requirement FIRST WORD
# 420              3 to 5 years       0.316667                                   3
# 507              3 to 7 years       0.316667                                   3
# 3196             3 to 7 years       0.350000                                   3
# 3562             3 to 5 years       0.350000                                   3
# 4478             3 to 5 years       0.316667                                   3
# 4739             4 to 5 years       0.350000                                   4
# 4875             4 to 5 years       0.333333                                   4
# 5608             4 to 5 years       0.443333                                   4
# 5934             4 to 5 years       0.330000                                   4
# 6227             3 to 7 years       0.340000                                   3
